# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
# carregando a base de dados
df = pd.read_csv("imoveis.csv", sep=",", encoding="utf-8")

correlacoes = df.corr()
fig, ax = plt.subplots()
sns.heatmap(correlacoes,square=True, annot=True)
plt.show()
